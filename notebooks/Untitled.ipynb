# %%
import xarray as xr
import rasterio as rio
# OUT_PREC
# OUT_EVAP
# OUT_RUNOFF
# OUT_BASEFLOW
# OUT_WDEW
# OUT_SOIL_LIQ
# OUT_SOIL_MOIST

# %% [markdown]
# # RVIC sample data structure

# %% [markdown]
# ## Domain

# %%
# dom_ref = xr.open_dataset("../extras/rvic_try2/RVIC/samples/domains/domain.lnd.bpa304.20140311.nc")
# dom_ref
# # Domain not opening

# %% [markdown]
# ## Parameters

# %%
param_ref = xr.open_dataset("/houston2/pritam/rat_mekong_v3/extras/rvic_try2/clipped.nc")
param_ref
# Out:
# <xarray.Dataset>
# Dimensions:         (lat: 388, lon: 237)
# Coordinates:
#   * lat             (lat) float64 9.603 9.665 9.728 9.79 ... 33.67 33.73 33.79
#   * lon             (lon) float64 93.91 93.97 94.03 94.09 ... 108.5 108.6 108.7
# Data variables:
#     Basin_ID        (lat, lon) float64 ...
#     Flow_Direction  (lat, lon) float64 ...
#     Flow_Distance   (lat, lon) float64 ...
#     Land_Mask       (lat, lon) float64 ...
#     Source_Area     (lat, lon) float64 ...
#     crs             |S1 ...
# Attributes:
#     Conventions:      CF-1.5
#     Source_Software:  ESRI ArcGIS
#     GDAL:             GDAL 1.10.0, released 2013/04/24
#     history:          Fri Jul 16 21:02:54 2021: ncks -d lon,93.875,108.6875 -...
#     NCO:              netCDF Operators version 5.0.1 (Homepage = http://nco.s...

# %%
param_ref.sel(lat=slice(9.594, 33.78), lon=slice(93.91, 108.7)).Flow_Distance
# Out:
# <xarray.DataArray 'Flow_Distance' (lat: 387, lon: 236)>
# array([[  nan,   nan,   nan, ...,   nan,   nan,   nan],
#        [  nan,   nan,   nan, ...,   nan,   nan,   nan],
#        [  nan,   nan,   nan, ...,   nan,   nan,   nan],
#        ...,
#        [5788., 5788., 5788., ..., 5788., 9044., 9044.],
#        [6949., 9042., 5784., ..., 6949., 5784., 6949.],
#        [5780., 5780., 6949., ..., 9039., 6949., 5780.]])
# Coordinates:
#   * lat      (lat) float64 9.603 9.665 9.728 9.79 ... 33.54 33.6 33.67 33.73
#   * lon      (lon) float64 93.97 94.03 94.09 94.16 ... 108.5 108.5 108.6 108.7
# Attributes:
#     long_name:       Flow_Distance
#     esri_pe_string:  GEOGCS["GCS_WGS_1984",DATUM["D_WGS_1984",SPHEROID["WGS_1...
#     units:           meter
