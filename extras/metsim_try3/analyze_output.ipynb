# %%
import xarray as xr
import matplotlib.pyplot as plt

# %%
ds = xr.open_dataset('./results/forcing_20010401-20010402.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 388, lon: 237, time: 24)
# Coordinates:
#   * time     (time) datetime64[ns] 2001-04-01 ... 2001-04-02T22:00:00
#   * lat      (lat) float64 33.78 33.72 33.66 33.59 ... 9.781 9.719 9.656 9.594
#   * lon      (lon) float64 93.91 93.97 94.03 94.09 ... 108.5 108.5 108.6 108.7
# Data variables:
#     temp     (time, lat, lon) float32 ...
#     prec     (time, lat, lon) float32 ...
#     sw       (time, lat, lon) float32 ...
#     lw       (time, lat, lon) float32 ...
#     spechum  (time, lat, lon) float32 ...
#     pres     (time, lat, lon) float32 ...
#     wind     (time, lat, lon) float32 ...
# Attributes: (12/32)
#     conventions:              1.6
#     title:                    Output from MetSim
#     institution:              University of Washington
#     source:                   metsim.py
#     history:                  Created: Mon Jul 12 16:55:57 2021 by pdas47
#     comment:                  no comment at this time
# ...
